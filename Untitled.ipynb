# %% [markdown]
# # Results

# %%
from IPython.display import Image, display

display(Image(filename=r"C:\Users\maria\OneDrive\Escritorio\ADRI\Q7 (Erasmus)\Introduction to Neural Networks\Neural_Networks\speedDating\Fotos\Captura de pantalla 2025-11-07 122306.png",width=1000))

# %% [markdown]
# ![Texto alternativo](C:/Users/maria/OneDrive/Escritorio/ADRI/Q7 (Erasmus)/Introduction to NeuralNetworks/Neural_Networks/speedDating/Fotos/Captura de pantalla 2025-11-07 115923.png
# )

# %% [markdown]
# ![Texto alternativo](fotos/)

# %% [markdown]
# "C:\Users\maria\OneDrive\Escritorio\ADRI\Q7 (Erasmus)\Introduction to Neural Networks\Neural_Networks\speedDating\Fotos\Captura de pantalla 2025-11-07 122306.png"
# "C:\Users\maria\OneDrive\Escritorio\ADRI\Q7 (Erasmus)\Introduction to Neural Networks\Neural_Networks\speedDating\Fotos\Captura de pantalla 2025-11-07 152603.png"
# "C:\Users\maria\OneDrive\Escritorio\ADRI\Q7 (Erasmus)\Introduction to Neural Networks\Neural_Networks\speedDating\Fotos\Captura de pantalla 2025-11-07 152921.png"
# "C:\Users\maria\OneDrive\Escritorio\ADRI\Q7 (Erasmus)\Introduction to Neural Networks\Neural_Networks\speedDating\Fotos\Captura de pantalla 2025-11-07 155354.png"
# "C:\Users\maria\OneDrive\Escritorio\ADRI\Q7 (Erasmus)\Introduction to Neural Networks\Neural_Networks\speedDating\Fotos\Captura de pantalla 2025-11-07 161427.png"
# "C:\Users\maria\OneDrive\Escritorio\ADRI\Q7 (Erasmus)\Introduction to Neural Networks\Neural_Networks\speedDating\Fotos\Captura de pantalla 2025-11-07 163944.png"
# "C:\Users\maria\OneDrive\Escritorio\ADRI\Q7 (Erasmus)\Introduction to Neural Networks\Neural_Networks\speedDating\Fotos\Captura de pantalla 2025-11-07 164736.png"
# "C:\Users\maria\OneDrive\Escritorio\ADRI\Q7 (Erasmus)\Introduction to Neural Networks\Neural_Networks\speedDating\Fotos\Captura de pantalla 2025-11-07 164834.png"
# "C:\Users\maria\OneDrive\Escritorio\ADRI\Q7 (Erasmus)\Introduction to Neural Networks\Neural_Networks\speedDating\Fotos\Captura de pantalla 2025-11-07 165203.png"
# "C:\Users\maria\OneDrive\Escritorio\ADRI\Q7 (Erasmus)\Introduction to Neural Networks\Neural_Networks\speedDating\Fotos\Captura de pantalla 2025-11-07 170420.png"
# "C:\Users\maria\OneDrive\Escritorio\ADRI\Q7 (Erasmus)\Introduction to Neural Networks\Neural_Networks\speedDating\Fotos\Captura de pantalla 2025-11-07 170449.png"
# "C:\Users\maria\OneDrive\Escritorio\ADRI\Q7 (Erasmus)\Introduction to Neural Networks\Neural_Networks\speedDating\Fotos\Captura de pantalla 2025-11-07 170522.png"
# "C:\Users\maria\OneDrive\Escritorio\ADRI\Q7 (Erasmus)\Introduction to Neural Networks\Neural_Networks\speedDating\Fotos\Captura de pantalla 2025-11-07 170636.png"
# "C:\Users\maria\OneDrive\Escritorio\ADRI\Q7 (Erasmus)\Introduction to Neural Networks\Neural_Networks\speedDating\Fotos\Captura de pantalla 2025-11-07 170652.png"
